# %% [markdown]
# ### This final code for the <span style="color:orange">'garfield'</span> function is designed to help facilitate prompt engineering by giving the engineer an accurate <span style="color:red">.csv</span> representation of the api response from the cat api, as well as counts to monitor token use and api calls.

# %%
import os
import json
from dotenv import load_dotenv
import requests
import pandas as pd
import numpy as np
import tiktoken
from datetime import datetime, timedelta

# set up the log for our cat api calls
cat_api_call_log = []

def garfield(save_path = "preened_cat_api_data.csv",
        limit = 10,
        verbose = False
            ):
    """
    Single function that calls The Cat API, flattens the JSON, and returns an easy-to-read .csv file for facilitated Prompt Engineering
    """

    global cat_api_call_log
    
    load_dotenv()
    cat_apikey = os.environ.get("cat_apikey")
    if not cat_apikey:
        raise ValueError("There is no 'cat_apikey' in your environment variables.")
    url = f"https://api.thecatapi.com/v1/images/search?size=med&mime_types=jpg&format=json&has_breeds=true&order=RANDOM&page=0&limit={limit}"
    headers = {
        'Content-Type': 'application/json',
        'x-api-key': cat_apikey
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        call_response = response.json()

        # track the call time and put it in the 'cat_api_call_log'
        now = datetime.now()
        cat_api_call_log.append(now)

        # number of api calls the past 24 hours
        cutoff = now - timedelta(days=1)
        recent_calls = [call for call in cat_api_call_log if call > cutoff]
        print(f"Number of API calls the last 24 hours: {len(recent_calls)}")

        
    except requests.exceptions.RequestException as e:
        print(f"Sorry. We could not execute your API call properly: {e}")
        return pd.DataFrame()  # empty fallback

    if verbose:
        print(json.dumps(call_response, indent=2))


    # running token count
    encoding = tiktoken.get_encoding("cl100k_base")
    token_count = len(encoding.encode(json.dumps(call_response)))

    print(f"Your api call consumed {token_count} tokens.")

    # flatten out the data
    data = []
    for item in call_response:
        for breed in item.get("breeds", []):
            data.append({
                "id": breed.get("id"), 
                "name": breed.get("name"), 
                "cfa_url": breed.get("cfa_url"),
                "vetstreet_url": breed.get("vetstreet_url"),
                "vcahospitals_url": breed.get("vcahospitals_url"), 
                "temperament": breed.get("temperament"), 
                "origin": breed.get("origin"), 
                "country_codes": breed.get("country_codes"),
                "country_code": breed.get("country_code"),
                "description": breed.get("description"),
                "life_span": breed.get("life_span"), 
                "indoor": breed.get("indoor"), 
                "lap": breed.get("lap"), 
                "alt_names": breed.get("alt_names"),
                "adaptability": breed.get("adaptability"),
                "affection_level": breed.get("affection_level"),
                "child_friendly": breed.get("child_friendly"),
                "dog_friendly": breed.get("dog_friendly"),
                "cat_friendly": breed.get("cat_friendly"),
                "energy_level": breed.get("energy_level"),
                "grooming": breed.get("grooming"),
                "health_issues": breed.get("health_issues"),
                "intelligence": breed.get("intelligence"),
                "shedding_level": breed.get("shedding_level"),
                "social_needs": breed.get("social_needs"),
                "stranger_friendly": breed.get("stranger_friendly"),
                "vocalisation": breed.get("vocalisation"),
                "experimental": breed.get("experimental"),
                "hairless": breed.get("hairless"),
                "natural": breed.get("natural"),
                "rare": breed.get("rare"),
                "rex": breed.get("rex"),
                "bidability": breed.get("bidability"),
                "suppressed_tail": breed.get("suppressed_tail"),
                "short_legs": breed.get("short_legs"),
                "wikipedia_url": breed.get("wikipedia_url"),
                "hypoallergenic": breed.get("hypoallergenic"),
                "reference_image_id": breed.get("reference_image_id"),
                "weight.imperial": breed.get("weight", {}).get("imperial"),
                "weight.metric": breed.get("weight", {}).get("metric"),
                "image_id": item.get("id"),
                "image_url": item.get("url")
            })

    api_df1 = pd.DataFrame(data)

    preferred_order = [
        "id", "name", "origin", "description", "alt_names", "temperament",
        "weight.metric", "weight.imperial", "intelligence", "child_friendly", "dog_friendly",
        "cat_friendly", "stranger_friendly", "energy_level","affection_level", "adaptability", 
        "indoor", "grooming", "hypoallergenic", "shedding_level", "life_span", "health_issues",
        "social_needs", "vocalisation", "lap", "natural", "experimental", "rare", "hairless", 
        "short_legs", "suppressed_tail", "bidability", "rex", "vcahospitals_url", "vetstreet_url",
        "cfa_url", "wikipedia_url", "image_url", "image_id", "reference_image_id", 
        "country_code", "country_codes"
    ]

    for column in preferred_order:
        if column not in api_df1.columns:
            api_df1[column] = np.nan

    api_df2 = api_df1[preferred_order]

    api_df2.to_csv(save_path, index=False)
    
    print(f"Your easy-to-read .csv file has been exported to: {save_path}")

    return api_df2

# %%
garfield()
# Out:
# Number of API calls the last 24 hours: 1
# Your api call consumed 4666 tokens.
# Your easy-to-read .csv file has been exported to: preened_cat_api_data.csv
#      id               name                origin  \
# 0  amau        Arabian Mau  United Arab Emirates
# 1  birm             Birman                France
# 2  bslo   British Longhair        United Kingdom
# 3  bsho  British Shorthair        United Kingdom
# 4  cymr             Cymric                Canada
# 5  nebe           Nebelung         United States
# 6  rblu       Russian Blue                Russia
# 7  sfol      Scottish Fold        United Kingdom
# 8  sphy             Sphynx                Canada
# 9  tvan        Turkish Van                Turkey
#
#                                          description  \
# 0  Arabian Mau cats are social and energetic. Due...
# 1  The Birman is a docile, quiet cat who loves pe...
# 2  The British Longhair is a very laid-back relax...
# 3  The British Shorthair is a very pleasant cat t...
# 4  The Cymric is a placid, sweet cat. They do not...
# 5  The Nebelung may have a reserved nature, but s...
# 6  Russian Blues are very loving and reserved. Th...
# 7  The Scottish Fold is a sweet, charming breed. ...
# 8  The Sphynx is an intelligent, inquisitive, ext...
# 9  While the Turkish Van loves to jump and climb,...
#
#                                    alt_names  \
# 0                                  Alley cat
# 1         Sacred Birman, Sacred Cat Of Burma
# 2
# 3  Highlander, Highland Straight, Britannica
# 4                                    Spangle
# 5                    Longhaired Russian Blue
# 6              Archangel Blue, Archangel Cat
# 7                                  Scot Fold
# 8         Canadian Hairless, Canadian Sphynx
# 9                  Turkish Cat, Swimming cat
#
#                                          temperament weight.metric  \
# 0  Affectionate, Agile, Curious, Independent, Pla...         4 - 7
# 1               Affectionate, Active, Gentle, Social         3 - 7
# 2  Affectionate, Easy Going, Independent, Intelli...         4 - 8
# 3  Affectionate, Easy Going, Gentle, Loyal, Patie...         5 - 9
# 4                Gentle, Loyal, Intelligent, Playful         4 - 6
# 5                        Gentle, Quiet, Shy, Playful         3 - 5
# 6  Active, Dependent, Easy Going, Gentle, Intelli...         2 - 5
# 7  Affectionate, Intelligent, Loyal, Playful, Soc...         2 - 5
# 8        Loyal, Inquisitive, Friendly, Quiet, Gentle         3 - 5
# 9      Agile, Intelligent, Loyal, Playful, Energetic         3 - 9
#
#   weight.imperial  intelligence  child_friendly  ...  rex  \
# 0          8 - 16             3               4  ...    0
# 1          6 - 15             3               4  ...    0
# 2          8 - 18             5               4  ...    0
# 3         12 - 20             3               4  ...    0
# 4          8 - 13             5               4  ...    0
# 5          7 - 11             5               4  ...    0
# 6          5 - 11             3               3  ...    0
# 7          5 - 11             3               4  ...    0
# 8          6 - 12             5               4  ...    0
# 9          7 - 20             5               4  ...    0
#
#                                     vcahospitals_url  \
# 0
# 1  https://vcahospitals.com/know-your-pet/cat-bre...
# 2                                               None
# 3  https://vcahospitals.com/know-your-pet/cat-bre...
# 4                                               None
# 5                                               None
# 6  https://vcahospitals.com/know-your-pet/cat-bre...
# 7  https://vcahospitals.com/know-your-pet/cat-bre...
# 8  https://vcahospitals.com/know-your-pet/cat-bre...
# 9  https://vcahospitals.com/know-your-pet/cat-bre...
#
#                                        vetstreet_url  \
# 0                                               None
# 1               http://www.vetstreet.com/cats/birman
# 2                                               None
# 3    http://www.vetstreet.com/cats/british-shorthair
# 4               http://www.vetstreet.com/cats/cymric
# 5                                               None
# 6  http://www.vetstreet.com/cats/russian-blue-neb...
# 7  http://www.vetstreet.com/cats/scottish-fold-hi...
# 8               http://www.vetstreet.com/cats/sphynx
# 9          http://www.vetstreet.com/cats/turkish-van
#
#                                              cfa_url  \
# 0                                               None
# 1         http://cfa.org/Breeds/BreedsAB/Birman.aspx
# 2                                               None
# 3  http://cfa.org/Breeds/BreedsAB/BritishShorthai...
# 4                                               None
# 5                                               None
# 6  http://cfa.org/Breeds/BreedsKthruR/RussianBlue...
# 7  http://cfa.org/Breeds/BreedsSthruT/ScottishFol...
# 8     http://cfa.org/Breeds/BreedsSthruT/Sphynx.aspx
# 9  http://cfa.org/Breeds/BreedsSthruT/TurkishVan....
#
#                                      wikipedia_url  \
# 0        https://en.wikipedia.org/wiki/Arabian_Mau
# 1             https://en.wikipedia.org/wiki/Birman
# 2   https://en.wikipedia.org/wiki/British_Longhair
# 3  https://en.wikipedia.org/wiki/British_Shorthair
# 4       https://en.wikipedia.org/wiki/Cymric_(cat)
# 5           https://en.wikipedia.org/wiki/Nebelung
# 6       https://en.wikipedia.org/wiki/Russian_Blue
# 7      https://en.wikipedia.org/wiki/Scottish_Fold
# 8       https://en.wikipedia.org/wiki/Sphynx_(cat)
# 9        https://en.wikipedia.org/wiki/Turkish_Van
#
#                                          image_url   image_id  \
# 0  https://cdn2.thecatapi.com/images/zlpgGWqN7.jpg  zlpgGWqN7
# 1  https://cdn2.thecatapi.com/images/9tZCXEYzy.jpg  9tZCXEYzy
# 2  https://cdn2.thecatapi.com/images/re7uO34hz.jpg  re7uO34hz
# 3  https://cdn2.thecatapi.com/images/_7U4xGLO_.jpg  _7U4xGLO_
# 4  https://cdn2.thecatapi.com/images/OLP-tyC2i.jpg  OLP-tyC2i
# 5  https://cdn2.thecatapi.com/images/FotU1pOJT.jpg  FotU1pOJT
# 6  https://cdn2.thecatapi.com/images/tHKLZkKZG.jpg  tHKLZkKZG
# 7  https://cdn2.thecatapi.com/images/_GVSjXZ4i.jpg  _GVSjXZ4i
# 8  https://cdn2.thecatapi.com/images/bSu2exlkB.jpg  bSu2exlkB
# 9  https://cdn2.thecatapi.com/images/RvfGGt00v.jpg  RvfGGt00v
#
#    reference_image_id  country_code  country_codes
# 0           k71ULYfRr            AE             AE
# 1           HOrX5gwLS            FR             FR
# 2           7isAO4Cav            GB             GB
# 3           s4wQfYoEk            GB             GB
# 4           3dbtapCWM            CA             CA
# 5           OGTWqNNOt            US             US
# 6           Rhj-JsTLP            RU             RU
# 7           o9t0LDcsa            GB             GB
# 8           BDb8ZXb1v            CA             CA
# 9           sxIXJax6h            TR             TR
#
# [10 rows x 42 columns]
